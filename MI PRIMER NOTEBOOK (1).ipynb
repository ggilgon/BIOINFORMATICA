# %% [markdown]
# # MI PRIMER NOTEBOOK

# %% [markdown]
# ### Este es mi primero notebook y voy a hacer esto:

# %% [markdown]
# Una lista **enumerada**:

# %% [markdown]
# 1. Primero
# 2. Segundo
# 3. Tercero

# %% [markdown]
# Una lista **por puntos**:

# %% [markdown]
# * Primero
# * Segundo
# * Tercero

# %% [markdown]
# Mi primer código:

# %%
mi_primera_frase = "Hola caracola"

# %%
print(mi_primera_frase)
# Out:
# Hola caracola

# %%
numeros = (55,678,990,34,56)

# %%
media = sum(numeros) /len(numeros)

# %%
print(media)
# Out:
# 362.6

# %% [markdown]
# ### Finalizamos con una bonita imagen

# %% [markdown]
# ![image.png](attachment:eadb897f-9b54-4c99-9f19-ceddafc6822e.png)
